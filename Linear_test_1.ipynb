# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data_set = pd.read_csv("dataset1.csv")
data_set
# Out:
#     CPU  Memory  Response Time
# 0    10      20            100
# 1    20      30            150
# 2    30      40            200
# 3    40      50            250
# 4    50      60            300
# 5    60      70            350
# 6    70      80            400
# 7    80      90            450
# 8    90     100            500
# 9   100     110            550
# 10  110     120            600
# 11  120     130            650
# 12  130     140            700
# 13  140     150            750
# 14  150     160            800
# 15  160     170            850
# 16  170     180            900
# 17  180     190            950
# 18  190     200           1000
# 19  200     210           1050

# %%
data_set.head()
# Out:
#    CPU  Memory  Response Time
# 0   10      20            100
# 1   20      30            150
# 2   30      40            200
# 3   40      50            250
# 4   50      60            300

# %%
data_set.dtypes
# Out:
# CPU              int64
# Memory           int64
# Response Time    int64
# dtype: object

# %%
print ("Missing Data")
print (data_set.isna().sum())
# Out:
# Missing Data
# CPU              0
# Memory           0
# Response Time    0
# dtype: int64

# %%
print (data_set.info)
# Out:
# <bound method DataFrame.info of     CPU  Memory  Response Time
# 0    10      20            100
# 1    20      30            150
# 2    30      40            200
# 3    40      50            250
# 4    50      60            300
# 5    60      70            350
# 6    70      80            400
# 7    80      90            450
# 8    90     100            500
# 9   100     110            550
# 10  110     120            600
# 11  120     130            650
# 12  130     140            700
# 13  140     150            750
# 14  150     160            800
# 15  160     170            850
# 16  170     180            900
# 17  180     190            950
# 18  190     200           1000
# 19  200     210           1050>

# %%
data_set.columns
# Out:
# Index(['CPU', 'Memory', 'Response Time'], dtype='str')

# %%
data_set.describe()
# Out:
#               CPU      Memory  Response Time
# count   20.000000   20.000000      20.000000
# mean   105.000000  115.000000     575.000000
# std     59.160798   59.160798     295.803989
# min     10.000000   20.000000     100.000000
# 25%     57.500000   67.500000     337.500000
# 50%    105.000000  115.000000     575.000000
# 75%    152.500000  162.500000     812.500000
# max    200.000000  210.000000    1050.000000

# %%
data_set.shape
# Out:
# (20, 3)

# %%
data_set.tail()
# Out:
#     CPU  Memory  Response Time
# 15  160     170            850
# 16  170     180            900
# 17  180     190            950
# 18  190     200           1000
# 19  200     210           1050

# %%
data_set.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CPU            20 non-null     int64
#  1   Memory         20 non-null     int64
#  2   Response Time  20 non-null     int64
# dtypes: int64(3)
# memory usage: 612.0 bytes

# %%
data_set.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Linearity Test

# %%
sns.lmplot(data = data_set, x = "CPU", y ="Response Time")

# %%
sns.lmplot(data = data_set, x = "Memory", y ="Response Time")

# %% [markdown]
# ## Normality Test

# %%
plt.hist(data_set["CPU"])
# Out:
# (array([2., 2., 2., 2., 2., 2., 2., 2., 2., 2.]),
#  array([ 10.,  29.,  48.,  67.,  86., 105., 124., 143., 162., 181., 200.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Corraltion Analysis

# %%
corr = data_set.corr()
corr
# Out:
#                CPU  Memory  Response Time
# CPU            1.0     1.0            1.0
# Memory         1.0     1.0            1.0
# Response Time  1.0     1.0            1.0

# %%
sns.heatmap (data = corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Data Perparation

# %%
X= data_set[["CPU","Memory"]]
X
# Out:
#     CPU  Memory
# 0    10      20
# 1    20      30
# 2    30      40
# 3    40      50
# 4    50      60
# 5    60      70
# 6    70      80
# 7    80      90
# 8    90     100
# 9   100     110
# 10  110     120
# 11  120     130
# 12  130     140
# 13  140     150
# 14  150     160
# 15  160     170
# 16  170     180
# 17  180     190
# 18  190     200
# 19  200     210

# %%
y = data_set[["Response Time"]]
y
# Out:
#     Response Time
# 0             100
# 1             150
# 2             200
# 3             250
# 4             300
# 5             350
# 6             400
# 7             450
# 8             500
# 9             550
# 10            600
# 11            650
# 12            700
# 13            750
# 14            800
# 15            850
# 16            900
# 17            950
# 18           1000
# 19           1050

# %% [markdown]
# ## Module Building

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20,shuffle=True)
X_train
# Out:
#     CPU  Memory
# 2    30      40
# 19  200     210
# 16  170     180
# 5    60      70
# 12  130     140
# 11  120     130
# 15  160     170
# 13  140     150
# 4    50      60
# 0    10      20
# 7    80      90
# 14  150     160
# 18  190     200
# 3    40      50
# 17  180     190
# 1    20      30

# %%
linear_model_test = LinearRegression()
linear_model_test
# Out:
# LinearRegression()

# %% [markdown]
# ## Model Training

# %%
linear_model_test.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linear_model_test.coef_
# Out:
# array([[2.5, 2.5]])

# %%
linear_model_test.intercept_
# Out:
# array([25.])

# %% [markdown]
# ## Model Testing

# %%
y_Preded_train= linear_model_test.predict(X_train)

# %%
y_Preded_train
# Out:
# array([[ 200.],
#        [1050.],
#        [ 900.],
#        [ 350.],
#        [ 700.],
#        [ 650.],
#        [ 850.],
#        [ 750.],
#        [ 300.],
#        [ 100.],
#        [ 450.],
#        [ 800.],
#        [1000.],
#        [ 250.],
#        [ 950.],
#        [ 150.]])

# %%
y_Preded_test= linear_model_test.predict(X_test)
y_Preded_test
# Out:
# array([[600.],
#        [550.],
#        [400.],
#        [500.]])

# %% [markdown]
# ## Model evulation

# %%
error = (y_train - y_Preded_train)
error
# Out:
#     Response Time
# 2   -8.526513e-14
# 19   0.000000e+00
# 16   0.000000e+00
# 5   -5.684342e-14
# 12   0.000000e+00
# 11   0.000000e+00
# 15   0.000000e+00
# 13   0.000000e+00
# 4   -5.684342e-14
# 0   -9.947598e-14
# 7   -5.684342e-14
# 14   0.000000e+00
# 18   1.136868e-13
# 3   -5.684342e-14
# 17   0.000000e+00
# 1   -8.526513e-14

# %%
y_Preded_train
# Out:
# array([[ 200.],
#        [1050.],
#        [ 900.],
#        [ 350.],
#        [ 700.],
#        [ 650.],
#        [ 850.],
#        [ 750.],
#        [ 300.],
#        [ 100.],
#        [ 450.],
#        [ 800.],
#        [1000.],
#        [ 250.],
#        [ 950.],
#        [ 150.]])

# %%
print(error.shape)
print(type(error))
# Out:
# (16, 1)
# <class 'pandas.DataFrame'>

# %% [markdown]
# ## Homoscedasticity test - From the error points, higher and lower predictions should be the same.

# %%
sns.scatterplot(x=data_set["CPU"], y =error)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 sns.scatterplot(x=data_set["CPU"], y =error)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)    612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %% [markdown]
# ## Zero Residaul Mean Test - Actual output and predicted output shoul be same

# %%
sns.scatterplot (x =data_set["CPU"], y = y_Preded.flatten())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from pickle import dump
dump(obj = linear_model, file =open (file ="Test_interlligence_file.pkl",mode ="wb"))

# %%
from pickle import load
Test_intel_pkl = load (file =open (file ="Test_interlligence_file.pkl",mode ="rb"))
Test_intel_pkl
# Out:
# LinearRegression()

# %% [raw]
# ## THE END

# %% [markdown]
# ##
